# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive/Colab\ Notebooks/alpha-zero-puyo
# !ls
# Out:
# /gdrive/MyDrive/Colab Notebooks/alpha-zero-puyo
# Arena.pyx  LICENSE   NeuralNet.pyx  puyo	 start.bat	  utils.pyx
# Coach.pyx  main.py   pit.bat	    __pycache__  temp
# Game.py    MCTS.pyx  pit.py	    README.md	 Untitled0.ipynb

# %%
# !pip install coloredlogs
# %load_ext Cython
# Out:
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.7/dist-packages (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.7/dist-packages (from coloredlogs) (9.2)

# %%
# !pip install torch==1.9.0+cu102 torchvision==0.10.0+cu102 torchaudio===0.9.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.9.0+cu102 in /usr/local/lib/python3.7/dist-packages (1.9.0+cu102)
# Requirement already satisfied: torchvision==0.10.0+cu102 in /usr/local/lib/python3.7/dist-packages (0.10.0+cu102)
# Requirement already satisfied: torchaudio===0.9.0 in /usr/local/lib/python3.7/dist-packages (0.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.0+cu102) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.10.0+cu102) (1.19.5)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.10.0+cu102) (7.1.2)

# %%
# !cp /gdrive/MyDrive/Colab\ Notebooks/alpha-zero-puyo/puyo/tuyotuyo.so /usr/lib/tuyotuyo.so
# Out:
# cp: '/gdrive/MyDrive/Colab Notebooks/alpha-zero-puyo/puyo/tuyotuyo.so' and '/usr/lib/tuyotuyo.so' are the same file

# %%
import pyximport; pyximport.install()

import logging

import coloredlogs

from Coach import Coach

from utils import *

log = logging.getLogger(__name__)

coloredlogs.install(level='INFO')  # Change this to DEBUG to see more info.

def main():
    log.info('Loading the Coach...')
    c = Coach()
    log.info('Starting the learning process 🎉')
    c.learn()


if __name__ == "__main__":
    import sys
    import os
    os.system("chcp 65001")
    main()
# Out:
# 2021-09-04 05:53:30 20e1a8234b51 __main__[6081] INFO Loading the Coach...
# 2021-09-04 05:53:30 20e1a8234b51 Coach[6081] INFO Loading 'trainExamples' from file...
# 2021-09-04 05:53:30 20e1a8234b51 Coach[6081] WARNING File "./temp/best.pth.tar.examples" with trainExamples not found!
# 2021-09-04 05:53:30 20e1a8234b51 __main__[6081] INFO Starting the learning process 🎉
# 2021-09-04 05:53:30 20e1a8234b51 Coach[6081] INFO Starting Iter #22 ...
# Self Play: 100%|██████████| 25/25 [00:11<00:00,  2.12it/s]
# Checkpoint Directory exists!
# EPOCH ::: 1
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 2
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 3
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 4
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 5
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 6
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 7
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 8
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 9
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 10
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 11
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 12
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 13
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 14
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 15
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 16
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 17
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 18
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 19
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 20
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 21
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 22
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 23
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 24
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 25
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 26
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 27
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 28
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 29
# Training Net: 0it [00:00, ?it/s]
# EPOCH ::: 30
# Training Net: 0it [00:00, ?it/s]
# 2021-09-04 05:53:44 20e1a8234b51 Coach[6081] INFO PITTING AGAINST PREVIOUS VERSION
# Arena.playGames (1):   0%|          | 0/5 [00:00<?, ?it/s]
# Turn  1 Player  1
# Turn  2 Player  -1
# Turn  3 Player  1
# Turn  4 Player  -1
# Turn  5 Player  1
# Turn  6 Player  -1
# Turn  7 Player  1
# Turn  8 Player  -1
# Turn  9 Player  1
# Turn  10 Player  -1
# Turn  11 Player  1
# Turn  12 Player  -1
# Turn  13 Player  -1
# Arena.playGames (1):  20%|██        | 1/5 [00:06<00:24,  6.18s/it]
# Turn  14 Player  1
# Game over: Turn  14 Result  1
# Turn  1 Player  1
# Turn  2 Player  -1
# Turn  3 Player  1
# Turn  4 Player  -1
# Turn  5 Player  1
# Turn  6 Player  -1
# Turn  7 Player  1
# Turn  8 Player  -1
# Turn  9 Player  1
# Turn  10 Player  -1
# Turn  11 Player  1
# Turn  12 Player  -1
# Turn  13 Player  1
# Turn  14 Player  -1
# Turn  15 Player  1
# Turn  16 Player  -1
# Turn  17 Player  -1
# Arena.playGames (1):  40%|████      | 2/5 [00:15<00:24,  8.30s/it]
# Turn  18 Player  1
# Game over: Turn  18 Result  1
# Turn  1 Player  1
# Turn  2 Player  -1
# Turn  3 Player  1
# Turn  4 Player  -1
# Turn  5 Player  1
# Turn  6 Player  -1
# Turn  7 Player  1
# Turn  8 Player  -1
# Turn  9 Player  1
# Turn  10 Player  -1
# Turn  11 Player  1
# Turn  12 Player  -1
# Turn  13 Player  1
# Turn  14 Player  -1
# Turn  15 Player  1
# Turn  16 Player  -1
# Turn  17 Player  -1
# Arena.playGames (1):  60%|██████    | 3/5 [00:24<00:16,  8.19s/it]
# Turn  18 Player  1
# Game over: Turn  18 Result  1
# Turn  1 Player  1
# Turn  2 Player  -1
# Turn  3 Player  1
# Turn  4 Player  -1
# Turn  5 Player  1
# Turn  6 Player  -1
# Turn  7 Player  1
# Turn  8 Player  -1
# Turn  9 Player  1
# Turn  10 Player  -1
# Turn  11 Player  1
# Turn  12 Player  -1
# Turn  13 Player  -1
# Turn  14 Player  1
# Arena.playGames (1):  80%|████████  | 4/5 [00:30<00:07,  7.36s/it]
# Game over: Turn  14 Result  1
# Turn  1 Player  1
# Turn  2 Player  -1
# Turn  3 Player  1
# Turn  4 Player  -1
# Turn  5 Player  1
# Turn  6 Player  -1
# Turn  7 Player  1
# Turn  8 Player  -1
# Turn  9 Player  1
# Turn  10 Player  -1
# Turn  11 Player  1
# Turn  12 Player  -1
# Turn  13 Player  1
# Turn  14 Player  -1
# Turn  15 Player  1
# Turn  16 Player  -1
