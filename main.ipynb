# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive/Colab\ Notebooks/alpha-zero-puyo
# !ls
# Out:
# /gdrive/MyDrive/Colab Notebooks/alpha-zero-puyo
# Arena.pyx  LICENSE   NeuralNet.pyx  puyo	 start.bat
# Coach.pyx  main.py   pit.bat	    __pycache__  Untitled0.ipynb
# Game.py    MCTS.pyx  pit.py	    README.md	 utils.pyx

# %%
# !pip install coloredlogs
# !pip install logging
# %load_ext Cython
# Out:
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.7/dist-packages (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.7/dist-packages (from coloredlogs) (9.2)
# Collecting logging
#   Using cached logging-0.4.9.6.tar.gz (96 kB)
# WARNING: Discarding https://files.pythonhosted.org/packages/93/4b/979db9e44be09f71e85c9c8cfc42f258adfb7d93ce01deed2788b2948919/logging-0.4.9.6.tar.gz#sha256=26f6b50773f085042d301085bd1bf5d9f3735704db9f37c1ce6d8b85c38f2417 (from https://pypi.org/simple/logging/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement logging (from versions: 0.4.9.6)
# ERROR: No matching distribution found for logging

# %%
# !cp /gdrive/MyDrive/Colab\ Notebooks/alpha-zero-puyo/puyo/tuyotuyo.so /usr/lib/tuyotuyo.so
# Out:
# cp: '/gdrive/MyDrive/Colab Notebooks/alpha-zero-puyo/puyo/tuyotuyo.so' and '/usr/lib/tuyotuyo.so' are the same file

# %%
import pyximport; pyximport.install()

import logging

import coloredlogs

from Coach import Coach

from utils import *

log = logging.getLogger(__name__)

coloredlogs.install(level='INFO')  # Change this to DEBUG to see more info.

def main():
    log.info('Loading the Coach...')
    c = Coach()
    log.info('Starting the learning process 🎉')
    c.learn()


if __name__ == "__main__":
    import sys
    import os
    os.system("chcp 65001")
    main()
# Out:
# 2021-09-04 05:45:24 20e1a8234b51 __main__[812] INFO Loading the Coach...
# 2021-09-04 05:45:25 20e1a8234b51 Coach[812] INFO Loading 'trainExamples' from file...
# 2021-09-04 05:45:25 20e1a8234b51 Coach[812] WARNING File "./temp/best.pth.tar.examples" with trainExamples not found!
# 2021-09-04 05:45:25 20e1a8234b51 __main__[812] INFO Starting the learning process 🎉
# 2021-09-04 05:45:25 20e1a8234b51 Coach[812] INFO Starting Iter #17 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-06c0491d948b> in <module>()
#      24     import os
#      25     os.system("chcp 65001")
# ---> 26     main()
#
# <ipython-input-5-06c0491d948b> in main()
#      17     c = Coach()
#      18     log.info('Starting the learning process 🎉')
# ---> 19     c.learn()
#      20
#      21
#
# /gdrive/MyDrive/Colab Notebooks/alpha-zero-puyo/Coach.pyx in Coach.Coach.learn()
#     129                 if self.args.load_model:
#     130                     #log.info('Loading checkpoint "%s/%s"...', args.load_folder_file)
# --> 131                     nnet.load_checkpoint(
#     132                         self.args.load_folder_file[0], self.args.load_folder_file[1])
#     133                 else:
#
# /gdrive/MyDrive/Colab Notebooks/alpha-zero-puyo/puyo/pytorch/NNet.pyx in puyo.pytorch.NNet.NNetWrapper.load_checkpoint()
#     119         filepath = os.path.join(folder, filename)
#     120         if not os.path.exists(filepath):
# --> 121             raise ("No model in path {}".format(filepath))
#     122         map_location = None if args.cuda else 'cpu'
#     123         checkpoint = torch.load(filepath, map_location=map_location)
#
# TypeError: raise: exception class must be a subclass of BaseException
